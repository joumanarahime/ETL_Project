# %%
import pandas as pd
from sqlalchemy import create_engine
import csv
import os.path
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory

# %%
csv_file=f"{cwd}/Resources/ACSST1Y2016.S1501_data_with_overlays_2019-10-30T152810.csv"
ACS_education_data = pd.read_csv(csv_file)
ACS_education_data.head()

# Share with student loan debt (%)
# Median student loan debt ($)
# Share student loan holders with student loan debt in collections (%)
# Median student loan debt in collections ($)
# Median monthly student loan payment ($)
# Share people with a credit record who have student loan debt in collections (%)
# Nonwhite population share (%)
# Share without a bachelor's degree (%)
# Average household income ($)


ACS_education_data = ACS_education_data.drop([0])
ACS_education_data.head()
# Out:
#            GEO_ID                     NAME S1501_C01_001E S1501_C01_001M  \
# 1  0500000US01003  Baldwin County, Alabama          15621           1652
# 2  0500000US01015  Calhoun County, Alabama          11440            736
# 3  0500000US01043  Cullman County, Alabama           7002            420
# 4  0500000US01049   DeKalb County, Alabama           5564            706
# 5  0500000US01051   Elmore County, Alabama           6948            952
#
#   S1501_C01_002E S1501_C01_002M S1501_C01_003E S1501_C01_003M S1501_C01_004E  \
# 1           3250           1219           3999           1248           7174
# 2           1398            601           4053            925           4918
# 3           1852            542           2341            578           2579
# 4            718            512           2227            833           2595
# 5            965            423           3203           1190           2462
#
# ...

# %%
df = ACS_education_data

df['county'] = df['NAME'].apply(lambda x: x.split(', ')[0])
df['state'] = df['NAME'].apply(lambda x: x.split(', ')[1])

df.head()
# Out:
#            GEO_ID                     NAME S1501_C01_001E S1501_C01_001M  \
# 1  0500000US01003  Baldwin County, Alabama          15621           1652
# 2  0500000US01015  Calhoun County, Alabama          11440            736
# 3  0500000US01043  Cullman County, Alabama           7002            420
# 4  0500000US01049   DeKalb County, Alabama           5564            706
# 5  0500000US01051   Elmore County, Alabama           6948            952
#
#   S1501_C01_002E S1501_C01_002M S1501_C01_003E S1501_C01_003M S1501_C01_004E  \
# 1           3250           1219           3999           1248           7174
# 2           1398            601           4053            925           4918
# 3           1852            542           2341            578           2579
# 4            718            512           2227            833           2595
# 5            965            423           3203           1190           2462
#
# ...

# %%
ACS_education_df = ACS_education_data[['GEO_ID', 'county','state', 'S1501_C01_001E', 'S1501_C01_004E', 'S1501_C01_005E',
                                     'S1501_C01_006E', 'S1501_C01_010E', 'S1501_C01_011E', 'S1501_C01_012E',
                                     'S1501_C01_013E','S1501_C02_001E', 'S1501_C02_004E', 'S1501_C02_005E',
                                     'S1501_C02_006E', 'S1501_C02_010E', 'S1501_C02_011E', 'S1501_C02_012E',
                                     'S1501_C02_013E']].copy()

ACS_education_df = ACS_education_df.rename(columns={'GEO_ID': 'GEO_ID'
                                                    , 'county': 'County'
                                                    , 'state': 'State'
                                                    , 'S1501_C01_001E': 'Pop_est_18-24' 
                                                    , 'S1501_C01_004E': 'Pop_est_18-24_some_college'
                                                    , 'S1501_C01_005E': 'Pop_est_18-24_Bachelor_degree'
                                                    , 'S1501_C01_006E': 'Pop_est_25+'
                                                    , 'S1501_C01_010E': 'Pop_est_25+_some_college'
                                                    , 'S1501_C01_011E': 'Pop_est_25+_Assoc_degree'
                                                    , 'S1501_C01_012E': 'Pop_est_25+_Bachelor_degree'
                                                    , 'S1501_C01_013E': 'Pop_est_25+_Graduate_degree'
                                                    , 'S1501_C02_001E': 'Pct_est_18-24' 
                                                    , 'S1501_C02_004E': 'Pct_est_18-24_some_college'
                                                    , 'S1501_C02_005E': 'Pct_est_18-24_Bachelor_degree'
                                                    , 'S1501_C02_006E': 'Pct_est_25+'
                                                    , 'S1501_C02_010E': 'Pct_est_25+_some_college'
                                                    , 'S1501_C02_011E': 'Pct_est_25+_Assoc_degree'
                                                    , 'S1501_C02_012E': 'Pct_est_25+_Bachelor_degree'
                                                    , 'S1501_C02_013E': 'Pct_est_25+_Graduate_degree'})
                                                     

ACS_education_df.head()
# Out:
#            GEO_ID          County    State Pop_est_18-24  \
# 1  0500000US01003  Baldwin County  Alabama         15621
# 2  0500000US01015  Calhoun County  Alabama         11440
# 3  0500000US01043  Cullman County  Alabama          7002
# 4  0500000US01049   DeKalb County  Alabama          5564
# 5  0500000US01051   Elmore County  Alabama          6948
#
#   Pop_est_18-24_some_college Pop_est_18-24_Bachelor_degree Pop_est_25+  \
# 1                       7174                          1198      146987
# 2                       4918                          1071       78218
# 3                       2579                           230       57469
# 4                       2595                            24       48227
# 5                       2462                           318       56224
#
#   Pop_est_25+_some_college Pop_est_25+_Assoc_degree  \
# 1                    31210                    15580
# 2                    21172                     5453
# ...

# %%
connection_string = "postgres:Kable$2649@localhost:5432/student_load_DB"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/student_load_DB)

# %%
ACS_education_df.columns
# Out:
# Index(['GEO_ID', 'County', 'State', 'Pop_est_18-24',
#        'Pop_est_18-24_some_college', 'Pop_est_18-24_Bachelor_degree',
#        'Pop_est_25+', 'Pop_est_25+_some_college', 'Pop_est_25+_Assoc_degree',
#        'Pop_est_25+_Bachelor_degree', 'Pop_est_25+_Graduate_degree',
#        'Pct_est_18-24', 'Pct_est_18-24_some_college',
#        'Pct_est_18-24_Bachelor_degree', 'Pct_est_25+',
#        'Pct_est_25+_some_college', 'Pct_est_25+_Assoc_degree',
#        'Pct_est_25+_Bachelor_degree', 'Pct_est_25+_Graduate_degree'],
#       dtype='object')

# %%
ACS_education_df.to_sql(name='ACS_education', con=engine, if_exists='append', index=True)
